# %%
import pandas as pd
data = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False], 
        ['Beltrano', 18, 9.3, True]]
dados = pd.DataFrame(data, 
        columns = ['Aluno', 'Idade', 'Nota', 'Aprovado'])
dados
# Out:
#       Aluno  Idade  Nota  Aprovado
# 0    Fulano     12   7.0      True
# 1   Sicrano     15   3.5     False
# 2  Beltrano     18   9.3      True

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, 
    columns = ['Tipos de Dados'])
tipos_de_dados.columns.name = 'Variáveis'
tipos_de_dados
# Out:
# Variáveis Tipos de Dados
# Aluno             object
# Idade              int64
# Nota             float64
# Aprovado            bool

# %%
# !pip install requests
# !pip install bs4
# !pip install lxml
# Out:
# Requirement already satisfied: requests in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from requests) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from requests) (2.0.12)
# Requirement already satisfied: bs4 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Requirement already satisfied: lxml in /Users/flavioalves/opt/anaconda3/envs/alura_pandas/lib/python3.6/site-packages (4.9.2)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url='https://www.federalreserve.gov/releases/h3/current/default.htm'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html.parser')
table = soup.findAll('table')
html_file = f'<html><body>{table}</body></html>'
df = pd.read_html(html_file)

# Como a função read_html retorna uma lista de DataFrames, basta acessar as tabelas pelos índices da lista.
# Como temos três tabelas na página usamos os índices 0, 1 ou 2 para acessar os DataFrames que buscamos
df[0]
# Out:
#                              Date   Reserve balances required  \
#    Reserve balance requirements 1 Top of penalty- free band 2
# 0                         Month 7                         NaN
# 1                       Aug. 2019                    134639.0
# 2                      Sept. 2019                    134707.0
# 3                       Oct. 2019                    134998.0
# 4                       Nov. 2019                    140705.0
# 5                       Dec. 2019                    138984.0
# 6                       Jan. 2020                    144816.0
# 7                       Feb. 2020                    138370.0
# 8                       Mar. 2020                    113139.0
# 9                       Apr. 2020                         0.0
# 10                       May 2020                         0.0
# 11                      June 2020                         0.0
# 12                      July 2020                         0.0
# 13                      Aug. 2020                         0.0
# 14                            NaN                         NaN
# 15             Two weeks ending 8                         NaN
# 16                  July 15, 2020                         0.0
# 17                  July 29, 2020                         0.0
# 18                  Aug. 12, 2020                         0.0
# 19                  Aug. 26, 2020                         0.0
# 20                  Sept. 9, 2020                         0.0
#
#     Reserve balances maintained 4 Unnamed: 3_level_0  \
#    Bottom of penalty- free band 3              Total
# 0                             NaN                NaN
# 1                        148114.0           121167.0
# 2                        148188.0           121227.0
# 3                        148509.0           121489.0
# 4                        154787.0           126625.0
# 5                        152893.0           125076.0
# 6                        159309.0           130326.0
# 7                        152218.0           124524.0
# 8                        124461.0           101817.0
# 9                             0.0                0.0
# 10                            0.0                0.0
# 11                            0.0                0.0
# 12                            0.0                0.0
# 13                            0.0                0.0
# 14                            NaN                NaN
# 15                            NaN                NaN
# 16                            0.0                0.0
# 17                            0.0                0.0
# 18                            0.0                0.0
# 19                            0.0                0.0
# 20                            0.0                0.0
#
#                                               Unnamed: 4_level_0  \
#    Balances maintained to satisfy reserve balance requirements 5
# 0                                                 NaN
# 1                                           1520876.0
# 2                                           1439771.0
# 3                                           1481513.0
# 4                                           1529341.0
# 5                                           1630090.0
# 6                                           1645384.0
# 7                                           1656989.0
# 8                                           2045148.0
# 9                                           2953586.0
# 10                                          3217635.0
# 11                                          3043556.0
# 12                                          2718529.0
# 13                                          2799719.0
# 14                                                NaN
# 15                                                NaN
# 16                                          2795785.0
# 17                                          2623526.0
# 18                                          2751124.0
# 19                                          2821740.0
# 20                                          2854690.0
#
#                                                     Unnamed: 5_level_0  \
#    Balances maintained that exceed the top of the penalty- free band 6
# 0                                                 NaN
# 1                                            147555.0
# 2                                            147498.0
# 3                                            148050.0
# 4                                            154256.0
# 5                                            152562.0
# 6                                            158765.0
# 7                                            151612.0
# 8                                            124147.0
# 9                                                 0.0
# 10                                                0.0
# 11                                                0.0
# 12                                                0.0
# 13                                                0.0
# 14                                                NaN
# 15                                                NaN
# 16                                                0.0
# 17                                                0.0
# 18                                                0.0
# 19                                                0.0
# 20                                                0.0
#
#    Unnamed: 6_level_0
#    Unnamed: 6_level_1
# 0                 NaN
# 1           1373321.0
# 2           1292273.0
# 3           1333462.0
# 4           1375085.0
# 5           1477528.0
# 6           1486619.0
# 7           1505377.0
# 8           1921000.0
# 9           2953586.0
# 10          3217635.0
# 11          3043556.0
# 12          2718529.0
# 13          2799719.0
# 14                NaN
# 15                NaN
# 16          2795785.0
# 17          2623526.0
# 18          2751124.0
# 19          2821740.0
# 20          2854690.0

# %%
import pandas as pd
dados = pd.DataFrame([1, 1, 2, 3, 3, 3, 4, 4], columns = ['X'])
dados
# Out:
#    X
# 0  1
# 1  1
# 2  2
# 3  3
# 4  3
# 5  3
# 6  4
# 7  4

# %%
len(dados)
# Out:
# 8

# %%
dados.drop_duplicates(inplace = True)
dados
# Out:
#    X
# 0  1
# 2  2
# 3  3
# 6  4

# %%
len(dados)
# Out:
# 4
